# %%
import tensorflow as tf
import numpy as np
from functools import partial
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Load MNIST data

# %%
#
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('datasets/mnist')
# Out:
# Extracting datasets/mnist\train-images-idx3-ubyte.gz
# Extracting datasets/mnist\train-labels-idx1-ubyte.gz
# Extracting datasets/mnist\t10k-images-idx3-ubyte.gz
# Extracting datasets/mnist\t10k-labels-idx1-ubyte.gz

# %% [markdown]
# Some settings

# %%
#
n_inputs = 28 * 28
n_hidden1 = 500
n_hidden2 = 500
n_hidden3 = 20 # codings 
n_hidden4 = n_hidden2 
n_hidden5 = n_hidden1 
n_outputs = n_inputs 
learning_rate = 0.001

# %% [markdown]
# Construct the architecture of the variational autoencoder

# %%
tf.reset_default_graph()

# %%
initializer = tf.contrib.layers.variance_scaling_initializer()
my_dense_layer = partial(tf.layers.dense, activation=tf.nn.elu,
                        kernel_initializer=initializer)

# %%
X = tf.placeholder(dtype=tf.float32, shape=[None, n_inputs])

# %%
with tf.name_scope('NN'):
    hidden1 = my_dense_layer(X, n_hidden1)
    hidden2 = my_dense_layer(hidden1, n_hidden2)
    hidden3_mean = my_dense_layer(hidden2, n_hidden3, activation=None)
    hidden3_gamma = my_dense_layer(hidden2, n_hidden3, activation=None)
    noise = tf.random_normal(tf.shape(hidden3_gamma), dtype=tf.float32)
    # hidden3 = N(hidden3_mean, sigma**2), where sigma = exp(gamma/2)
    hidden3 = hidden3_mean + tf.exp(0.5 * hidden3_gamma) * noise
    hidden4 = my_dense_layer(hidden3, n_hidden4)
    hidden5 = my_dense_layer(hidden4, n_hidden5)
    logits = my_dense_layer(hidden5, n_outputs, activation=None)
    outputs = tf.nn.sigmoid(logits)

# %% [markdown]
# Define the loss function

# %% [markdown]
# The reconstruction loss is squared error or entropy. Don't average over input dimension.
#
# For the $i$-th data point, the latent loss is
# $L_i = 0.5 \times \sum_{j=1}^D (\mu_j^2 + \sigma_j^2 - \log(\sigma_j^2) -1) $ where D is the dimension of the coding layer, and D=20 in this example. Based on $\sigma^2 = \exp{(\gamma)}$, we have
#
# $L_i = 0.5 \times \sum_{j=1}^D (\mu_j^2 + \exp(\gamma_j) - \gamma_j -1) $
#
# Then the total latent error is $L=\sum_{i=1}^m L_i$ where m is the number of data points. {Don't average over coding dimension.}

# %%
with tf.name_scope('loss'):
    # the reconstruction error
    entropy = tf.nn.sigmoid_cross_entropy_with_logits(labels=X, logits=logits)
    reconstruction_loss = tf.reduce_sum(entropy) # sum, not mean

    # the latent loss (K-L divergence)
    latent_loss = 0.5 * tf.reduce_sum(tf.exp(hidden3_gamma) 
                                      + tf.square(hidden3_mean)
                                      - 1 - hidden3_gamma)

    # the total loss
    loss = reconstruction_loss + latent_loss

# %% [markdown]
# Define optimizer

# %%
with tf.name_scope('train'):
    optimizer = tf.train.AdamOptimizer()
    train_op = optimizer.minimize(loss)

# %% [markdown]
# Training

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

n_epoch = 50
batch_size = 150
n_batch = mnist.train.num_examples // batch_size
n_digits = 60

# %%
with tf.Session() as sess:
    sess.run(init)
    
    for epoch in range(n_epoch):
        for batch in range(n_batch):
            X_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(train_op, feed_dict={X: X_batch})
        loss_val = sess.run(loss, feed_dict={X: mnist.train.images})
        print('Epoch: {}, validation error: {:.4f}'.format(epoch+1, loss_val))
    
    saver.save(sess, 'tmp/VAE.ckpt')
# Out:
# Epoch: 1, validation error: 6693498.0000
# Epoch: 2, validation error: 6305546.5000
# Epoch: 3, validation error: 6129547.0000
# Epoch: 4, validation error: 6039227.5000
# Epoch: 5, validation error: 5962653.0000
# Epoch: 6, validation error: 5880605.0000
# Epoch: 7, validation error: 5859555.0000
# Epoch: 8, validation error: 5829610.0000
# Epoch: 9, validation error: 5804364.5000
# Epoch: 10, validation error: 5769393.0000
# Epoch: 11, validation error: 5746757.0000
# Epoch: 12, validation error: 5728072.0000
# Epoch: 13, validation error: 5699699.0000
# Epoch: 14, validation error: 5681130.5000
# Epoch: 15, validation error: 5684634.5000
# Epoch: 16, validation error: 5666358.0000
# Epoch: 17, validation error: 5634686.0000
# Epoch: 18, validation error: 5646650.5000
# Epoch: 19, validation error: 5643686.0000
# Epoch: 20, validation error: 5585682.0000
# Epoch: 21, validation error: 5576655.0000
# Epoch: 22, validation error: 5571439.5000
# Epoch: 23, validation error: 5568263.0000
# Epoch: 24, validation error: 5560236.5000
# Epoch: 25, validation error: 5565782.0000
# Epoch: 26, validation error: 5534544.0000
# Epoch: 27, validation error: 5524672.5000
# Epoch: 28, validation error: 5536408.0000
# Epoch: 29, validation error: 5530626.0000
# Epoch: 30, validation error: 5502739.5000
# Epoch: 31, validation error: 5500608.0000
# Epoch: 32, validation error: 5506676.0000
# Epoch: 33, validation error: 5525448.0000
# Epoch: 34, validation error: 5483544.0000
# Epoch: 35, validation error: 5483735.0000
# Epoch: 36, validation error: 5450144.5000
# Epoch: 37, validation error: 5488632.0000
# Epoch: 38, validation error: 5462934.0000
# Epoch: 39, validation error: 5466043.0000
# Epoch: 40, validation error: 5468151.0000
# Epoch: 41, validation error: 5447297.5000
# Epoch: 42, validation error: 5453863.0000
# Epoch: 43, validation error: 5450016.0000
# Epoch: 44, validation error: 5452830.0000
# Epoch: 45, validation error: 5435356.0000
# Epoch: 46, validation error: 5429063.0000
# Epoch: 47, validation error: 5422661.0000
# Epoch: 48, validation error: 5429768.5000
# Epoch: 49, validation error: 5418968.0000
# Epoch: 50, validation error: 5422820.0000

# %%
with tf.Session() as sess:
    saver.restore(sess, 'tmp/VAE.ckpt')
    codings_rnd = np.random.normal(size=[n_digits, n_hidden3])
    output_val = sess.run(outputs, feed_dict={hidden3: codings_rnd})
# Out:
# INFO:tensorflow:Restoring parameters from tmp/VAE.ckpt

# %% [markdown]
# Visualize generated digits

# %%
fig, axes = plt.subplots(6, 10, figsize=(10, 6))
axes_flat = axes.ravel()
for i in range(n_digits):
    axes_flat[i].imshow(output_val[i].reshape((28, -1)), cmap='gray')
    axes_flat[i].get_xaxis().set_visible(False)
    axes_flat[i].get_yaxis().set_visible(False)
